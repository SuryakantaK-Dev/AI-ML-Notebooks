# %%
# !git clone https://github.com/OpenGVLab/Multitask-Model-Selector.git
# Out:
# Cloning into 'Multitask-Model-Selector'...
# remote: Enumerating objects: 78, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 78 (delta 0), reused 0 (delta 0), pack-reused 75 (from 1)
# Receiving objects: 100% (78/78), 380.60 KiB | 2.01 MiB/s, done.
# Resolving deltas: 100% (33/33), done.

# %%
# %cd Multitask-Model-Selector
# Out:
# /content/Multitask-Model-Selector

# %%
# !pip install -r requirements.txt
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %% [markdown]
# Extract features of target data using pretrained models and different labels of target data
#
# Image classification with CNN models

# %%
cd Label_embedding
# Out:
# /content/Multitask-Model-Selector/Label_embedding

# %%
# !python clip.py
# !python bert.py
# !python gpt2.py
# Out:
# config.json: 100% 4.61k/4.61k [00:00<00:00, 19.4MB/s]
# model.safetensors: 100% 5.47G/5.47G [05:37<00:00, 16.2MB/s]
# 2024-09-21 18:29:30.344532: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-21 18:29:30.635084: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-21 18:29:30.720285: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-21 18:29:30.795511: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-21 18:29:32.809346: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# preprocessor_config.json: 100% 316/316 [00:00<00:00, 1.83MB/s]
# tokenizer_config.json: 100% 904/904 [00:00<00:00, 5.44MB/s]
# vocab.json: 100% 862k/862k [00:00<00:00, 1.07MB/s]
# merges.txt: 100% 525k/525k [00:00<00:00, 877kB/s]
# tokenizer.json: 100% 2.22M/2.22M [00:01<00:00, 2.22MB/s]
# special_tokens_map.json: 100% 389/389 [00:00<00:00, 2.23MB/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# 47 dtd
# torch.Size([47, 1024])
# Traceback (most recent call last):
#   File "/content/Multitask-Model-Selector/Label_embedding/clip.py", line 51, in <module>
#     np.save('/data/feature_bnorm_classification_1024/' + dataset + '_clip_1024_nonorm.npy',embeddings.cpu())
#   File "/usr/local/lib/python3.10/dist-packages/numpy/lib/npyio.py", line 542, in save
#     file_ctx = open(file, "wb")
# FileNotFoundError: [Errno 2] No such file or directory: '/data/feature_bnorm_classification_1024/dtd_clip_1024_nonorm.npy'
# tokenizer_config.json: 100% 48.0/48.0 [00:00<00:00, 257kB/s]
# config.json: 100% 571/571 [00:00<00:00, 3.37MB/s]
# vocab.txt: 100% 232k/232k [00:00<00:00, 581kB/s]
# tokenizer.json: 100% 466k/466k [00:00<00:00, 1.16MB/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# model.safetensors: 100% 1.34G/1.34G [01:09<00:00, 19.3MB/s]
# 47 dtd
# 100 aircraft
# 102 caltech101
# 196 cars
# 10 cifar10
# 100 cifar100
# 102 flowers
# 101 food
# 37 pets
# 397 sun397
# 20 voc2007
# tokenizer_config.json: 100% 26.0/26.0 [00:00<00:00, 146kB/s]
# vocab.json: 100% 1.04M/1.04M [00:00<00:00, 1.30MB/s]
# merges.txt: 100% 456k/456k [00:00<00:00, 764kB/s]
# tokenizer.json: 100% 1.36M/1.36M [00:00<00:00, 1.70MB/s]
# config.json: 100% 718/718 [00:00<00:00, 3.92MB/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# model.safetensors: 100% 1.52G/1.52G [00:14<00:00, 101MB/s]
# 47 dtd
# 100 aircraft
# 102 caltech101
# 196 cars
# 10 cifar10
# 100 cifar100
# 102 flowers
# 101 food
# 37 pets
# 397 sun397
# 20 voc2007
